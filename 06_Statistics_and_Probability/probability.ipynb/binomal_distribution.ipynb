# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
n=10
p=0.5
binomial=np.random.binomial(n,p,1000)

# %%
unique,counts=np.unique(binomial,return_counts=True)
probablity=counts/1000

# %%
for i ,val in enumerate(unique):
    print(f"  P(X={val}) = {probablity[i]:.3f}")
# Out:
#   P(X=0) = 0.002
#   P(X=1) = 0.010
#   P(X=2) = 0.043
#   P(X=3) = 0.114
#   P(X=4) = 0.218
#   P(X=5) = 0.238
#   P(X=6) = 0.206
#   P(X=7) = 0.118
#   P(X=8) = 0.042
#   P(X=9) = 0.009

# %%
from scipy.stats  import binom
thoerictcal=binom.pmf(5,n,p)
print(thoerictcal)
# Out:
# 0.2460937500000002
