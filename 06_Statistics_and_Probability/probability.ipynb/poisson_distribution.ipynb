# %%
lambda_=5
poisson=np.random.randint(lambda_,1000)
print(poisson)
# Out:
# 259

# %%
import numpy as np
unique,counts=np.unique(poisson,return_counts=True)
prob=counts/1000

# %%
for i in range (5):
    if i < len(unique):
        print(prob)
# Out:
# [0.001]

# %% [markdown]
# ## Q--2

# %%
from scipy.stats import poisson
lamba_=4
porbab=poisson.pmf(3,mu=lamba_)
print(porbab)
# Out:
# 0.19536681481316454
