# %%
import pandas as pd
import numpy as np
import yfinance as yf
# Out:
# /Users/krishna/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
df = yf.download("TCS.NS", period="6mo")
df = df[['Close']].copy()
df.index = pd.to_datetime(df.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### questions
#  --------------------------------------------------
# # Q1: Display the last 5 rows of the DataFrame.
# # --------------------------------------------------
#
# # --------------------------------------------------
# # Q2: What is the data type of the index? Write code to check.
# # --------------------------------------------------
#
# # --------------------------------------------------
# # Q3: Resample the daily data to monthly frequency (use month end) and store in `monthly`.
# #     Then display the first 3 rows of `monthly`.
# # --------------------------------------------------
#
# # --------------------------------------------------
# # Q4: Resample the daily data to weekly frequency (last trading day of week) and compute
# #     the weekly returns (percentage change from previous week's close).
# # --------------------------------------------------
#
# # --------------------------------------------------
# # Q5: Create a new column 'SMA_20' that is the 20‑day simple moving average of the close price.
# # --------------------------------------------------
#
# # --------------------------------------------------
# # Q6: Create a new column 'volatility_20' that is the 20‑day rolling standard deviation of daily returns.
# #     (First compute daily returns using `.pct_change()`.)
# # --------------------------------------------------
#
# # --------------------------------------------------
# # Q7: Use `.shift(1)` to create a new column 'Close_prev' containing yesterday's closing price.
# # --------------------------------------------------
#
# # --------------------------------------------------
# # Q8: Calculate daily returns using `.pct_change()` and store in a new column 'daily_return'.
# # --------------------------------------------------
#
# # --------------------------------------------------
# # Q9: Find the date when the daily return was highest (maximum) over the entire period.
# # --------------------------------------------------
#
# # --------------------------------------------------
# # Q10: Create a new DataFrame that contains only the data for the month of March (all days in March)

# %%
df.tail(5)
# Out:
# Price             Close
# Ticker           TCS.NS
# Date
# 2026-06-05  2198.899902
# 2026-06-08  2151.399902
# 2026-06-09  2151.000000
# 2026-06-10  2153.899902
# 2026-06-11  2135.600098

# %%
print(df.index.dtype)
# Out:
# datetime64[ns]

# %%
resampling=df.resample('M').last()
print(df.tail(3))
# Out:
# Price             Close
# Ticker           TCS.NS
# Date
# 2026-06-09  2151.000000
# 2026-06-10  2153.899902
# 2026-06-11  2135.600098
# /var/folders/nq/gbr6n11x7tl008w0734b10z00000gn/T/ipykernel_2058/3788155730.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   resampling=df.resample('M').last()

# %%
weekly=df.resample('W').last()
weekly['weekly_return']=weekly['Close'].pct_change()
print(weekly.head(5))
# Out:
# Price             Close weekly_return
# Ticker           TCS.NS
# Date
# 2025-12-14  3120.686523           NaN
# 2025-12-21  3180.280518      0.019096
# 2025-12-28  3178.342529     -0.000609
# 2026-01-04  3149.950439     -0.008933
# 2026-01-11  3108.380127     -0.013197

# %%
from pandas.core import window
df['SMA-20']=df['Close'].rolling(window=20).mean()

# %%
df['daily_return']=df['Close'].pct_change()
df['Volatility-20']=df['daily_return'].rolling(window=20).std()

# %%
close_prev=df["Close"].shift(1)
print(close_prev)
# Out:
# Ticker           TCS.NS
# Date
# 2025-12-11          NaN
# 2025-12-12  3092.972900
# 2025-12-15  3120.686523
# 2025-12-16  3130.085938
# 2025-12-17  3105.763916
# ...                 ...
# 2026-06-05  2241.000000
# 2026-06-08  2198.899902
# 2026-06-09  2151.399902
# 2026-06-10  2151.000000
# 2026-06-11  2153.899902
#
# [124 rows x 1 columns]

# %%
df['daily_return']=df['Close'].pct_change()
# Out:
# ['daily_return']

# %%
max_return_date = df['daily_return'].idxmax()
print(max_return_date)
# Out:
# NaT
# /var/folders/nq/gbr6n11x7tl008w0734b10z00000gn/T/ipykernel_2058/2401694753.py:1: FutureWarning: The behavior of Series.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   max_return_date = df['daily_return'].idxmax()

# %%
march_data = df.loc['2024-03-01':'2024-03-31']
print(march_data.head())
# Out:
# Empty DataFrame
# Columns: [(Close, TCS.NS), (SMA-20, ), (daily_return, ), (Volatility-20, )]
# Index: []
